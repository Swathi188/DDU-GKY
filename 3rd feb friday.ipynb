# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dff=pd.read_csv('netflix_titles_2021.csv')
dff.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df=a
a
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
pivot2=pd.pivot_table(columns='rating',values='release_year',data=a,aggfunc='median')
pivot2
# Out:
# rating           G    PG  PG-13     R  TV-14  TV-G  TV-MA  TV-PG  TV-Y  TV-Y7
# release_year  2020  2020   2020  2020   2020  2020   2020   2020  2020   2020

# %%
df.assign(after_2020=df['release_year']>2020)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
a=df.assign(before_2000=df['release_year']<2000)

# %%
df2=df.query('release_year==2020&type=="Movie"')
df2.head()
# Out:
#     show_id   type                                              title  \
# 0        s1  Movie                               Dick Johnson Is Dead
# 16      s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78      s79  Movie                                     Tughlaq Durbar
# 84      s85  Movie                               Omo Ghetto: the Saga
# 103    s104  Movie                                     Shadow Parties
#
#                                           director  \
# 0                                  Kirsten Johnson
# 16   Pedro de Echave García, Pablo Azorín Williams
# 78                        Delhiprasad Deenadayalan
# 84                      JJC Skillz, Funke Akindele
# 103                                     Yemi Amodu
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 16                                                 NaN            NaN
# ...

# %%
df3=df.dropna(subset=['cast'])
df3.head()
# Out:
#     show_id   type                 title                    director  \
# 78      s79  Movie        Tughlaq Durbar    Delhiprasad Deenadayalan
# 84      s85  Movie  Omo Ghetto: the Saga  JJC Skillz, Funke Akindele
# 103    s104  Movie        Shadow Parties                  Yemi Amodu
# 119    s120  Movie        Here and There                    JP Habac
# 126    s127  Movie               Shikara          Vidhu Vinod Chopra
#
#                                                   cast  country  \
# 78          Vijay Sethupathi, Parthiban, Raashi Khanna      NaN
# 84   Funke Akindele, Ayo Makun, Chioma Chukwuka Akp...  Nigeria
# 103  Jide Kosoko, Omotola Jalade-Ekeinde, Yemi Blaq...      NaN
# 119  Janine Gutierrez, JC Santos, Victor Anastacio,...      NaN
# 126  Aadil Khan, Sadia Khateeb, Zain Khan Durrani, ...    India
#
#              date_added  release_year rating duration  \
# 78   September 11, 2021          2020  TV-14  145 min
# ...

# %%
df3=df.dropna(subset=['director'])
df3.head()
# Out:
#     show_id   type                                              title  \
# 0        s1  Movie                               Dick Johnson Is Dead
# 16      s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78      s79  Movie                                     Tughlaq Durbar
# 84      s85  Movie                               Omo Ghetto: the Saga
# 103    s104  Movie                                     Shadow Parties
#
#                                           director  \
# 0                                  Kirsten Johnson
# 16   Pedro de Echave García, Pablo Azorín Williams
# 78                        Delhiprasad Deenadayalan
# 84                      JJC Skillz, Funke Akindele
# 103                                     Yemi Amodu
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 16                                                 NaN            NaN
# ...

# %%
df
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
df3=df.isnull().sum()
df3.head()
# Out:
# show_id      0
# type         0
# title        0
# director     0
# cast        37
# dtype: int64

# %%
df4=df.drop(columns=['cast','description'])
df4.head()
# Out:
#     show_id   type                                              title  \
# 0        s1  Movie                               Dick Johnson Is Dead
# 16      s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78      s79  Movie                                     Tughlaq Durbar
# 84      s85  Movie                               Omo Ghetto: the Saga
# 103    s104  Movie                                     Shadow Parties
#
#                                           director        country  \
# 0                                  Kirsten Johnson  United States
# 16   Pedro de Echave García, Pablo Azorín Williams            NaN
# 78                        Delhiprasad Deenadayalan            NaN
# 84                      JJC Skillz, Funke Akindele        Nigeria
# 103                                     Yemi Amodu            NaN
#
#              date_added  release_year rating duration  \
# 0    September 25, 2021          2020  PG-13   90 min
# ...

# %%
pivot=pd.pivot_table(columns='rating',values='release_year',data=a,aggfunc='median')
pivot
# Out:
# rating           G    PG  PG-13     R  TV-14  TV-G  TV-MA  TV-PG  TV-Y  TV-Y7
# release_year  2020  2020   2020  2020   2020  2020   2020   2020  2020   2020

# %%
pivot.T
# Out:
#         release_year
# rating
# G               2020
# PG              2020
# PG-13           2020
# R               2020
# TV-14           2020
# TV-G            2020
# TV-MA           2020
# TV-PG           2020
# TV-Y            2020
# TV-Y7           2020

# %%
df
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
a
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
dff
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
pivot=pd.pivot_table(columns='rating',values='release_year',data=dff,aggfunc='median')
pivot
# Out:
# rating        66 min  74 min  84 min     G  NC-17    NR    PG  PG-13     R  \
# release_year    2015    2017    2010  2004   2014  2015  2012   2011  2014
#
# rating        TV-14  TV-G  TV-MA  TV-PG  TV-Y  TV-Y7  TV-Y7-FV    UR
# release_year   2017  2018   2018   2017  2018   2017      2015  2008

# %%
pivot=pd.pivot_table(columns='rating',values='release_year',data=dff,aggfunc='median')
pivot.T
# Out:
#           release_year
# rating
# 66 min            2015
# 74 min            2017
# 84 min            2010
# G                 2004
# NC-17             2014
# NR                2015
# PG                2012
# PG-13             2011
# R                 2014
# TV-14             2017
# TV-G              2018
# TV-MA             2018
# TV-PG             2017
# TV-Y              2018
# TV-Y7             2017
# TV-Y7-FV          2015
# UR                2008

# %%
marklist={'name':['abhimanyu','ajith','akshay','alen','anand','ansal','arun','aswin','dhavood','haripriya','indrajith','jishnu','jishnuraj','jopika','keerthi','kiran','lubna','mancy','merlin','safeer','siraj','nandakrishnan','najmi','nida','rahul','ramshad','sanika','sanoy','shammas','smijith','sneha','soorya','swathi','vidya','vishnu'],
          'python':[24,25,24,25,25,25,24,24,24,24,25,25,23,24,25,24,24,25,24,24,24,0,25,25,25,25,25,24,24,24,22,24,25,23,24],
          'statistics':[15,15,18,18,16,19,15,13,16,17,13,15,15,13,16,20,16,16,16,15,19,0,13,15,16,19,17,15,17,13,13,16,16,17,17],
          'total':[39,40,42,43,41,44,39,37,40,41,38,40,38,37,41,44,40,41,40,39,43,0,38,40,41,44,42,39,41,37,35,40,41,40,41],
          'percentage':[86.67,88.89,93.33,95.56,91.11,97.78,86.67,82.22,88.89,91.11,84.44,88.89,84.44,82.22,91.11,97.78,88.89,91.11,88.89,86.67,95.56,0,84.44,88.89,91.11,97.78,93.33,86.67,91.11,82.22,77.78,88.89,91.11,88.89,91.11],
         }
df=pd.DataFrame(marklist)
df.head()
# Out:
#         name  python  statistics  total  percentage
# 0  abhimanyu      24          15     39       86.67
# 1      ajith      25          15     40       88.89
# 2     akshay      24          18     42       93.33
# 3       alen      25          18     43       95.56
# 4      anand      25          16     41       91.11

# %%
#to_csv()
df.to_csv('marklist.csv')
