# %% [markdown]
# # DEFAULT DATASETS
# seaborn

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the datasets contained in the seaborn libraray

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #### Load as a dataframe

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   species       149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df.value_counts('species')
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# dtype: int64

# %%
sns.countplot(x='species',data=df)
plt.show()

# %%
sns.kdeplot(x='petal_length',data=df)
plt.show()

# %%
sns.kdeplot(x='petal_width',data=df)
plt.show()

# %%
sns.kdeplot(x='sepal_length',data=df)
plt.show()

# %%
sns.kdeplot(x='sepal_width',data=df)
plt.show()

# %%
sns.histplot(x='petal_length',data=df)
plt.show()

# %%
sns.histplot(x='petal_width',data=df)
plt.show()

# %%
sns.boxplot(x='petal_width',data=df)
plt.show()

# %%
sns.boxplot(y='petal_width',data=df)
plt.show()

# %%
sns.lineplot(x='petal_width',data=df,y='sepal_width')
plt.show()

# %%
sns.set_style('ticks')
sns.factorplot('petal_width','sepal_width',data=df)
plt.show()

# %%
sns.set_style('dark')
plt.figure(figsize=(5,3))
sns.violinplot('sepal_width','petal_width',data=df)
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
heat_map=df.corr()
sns.heatmap(heat_map)
plt.show()

# %%
df.plot.hist(subplots=True);

# %%
df.plot.hexbin('sepal_width','petal_width',gridsize=15,cmap='summer');

# %%
df.sort_values(by='sepal_width', ascending=False)[:10].sepal_width.plot.pie();

# %%
df.sort_values(by='petal_width')[:10].plot.scatter('sepal_length','petal_width',figsize=(10,3));

# %%
df.plot.area('sepal_length','petal_width',figsize=(10,3),cmap='ocean');

# %%
df.plot.kde(figsize=(10,5));

# %%
df.plot.kde(figsize=(20,8), subplots=True);

# %%
df.plot.box(figsize=(20,8));
